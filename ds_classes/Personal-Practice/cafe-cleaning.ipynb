# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cafe_sales = pd.read_csv("dirty_cafe_sales.csv")

# %%
cafe_sales
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
cafe_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9031 non-null   object
#  2   Quantity          9521 non-null   object
#  3   Price Per Unit    9467 non-null   object
#  4   Total Spent       9498 non-null   object
#  5   Payment Method    6822 non-null   object
#  6   Location          6039 non-null   object
#  7   Transaction Date  9540 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
cafe_sales.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
cafe_sales = cafe_sales.replace(["ERROR", "UNKNOWN"], py.nan)

# %%
num_colums = ["Quantity", "Price Per Unit", "Total Spent"]

for x in num_colums:
    cafe_sales[x] = pd.to_numeric(cafe_sales[x])

# %%
for x in num_colums:
    cafe_sales[x] = cafe_sales[x].fillna(cafe_sales[x].mean())

# %%
cat_colums = ["Item", "Payment Method", "Location"]

for x in cat_colums:
    cafe_sales[x] = cafe_sales[x].fillna(cafe_sales[x].mode()[0])

# %%
cafe_sales["Transaction Date"] = cafe_sales["Transaction Date"].fillna(cafe_sales["Transaction Date"].mode()[0])

# %%
cafe_sales.isna().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
cafe_sales
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0        2.000000     4.000000
# 1       TXN_4977031      Cake       4.0        3.000000    12.000000
# 2       TXN_4271903    Cookie       4.0        1.000000     8.924352
# 3       TXN_7034554     Salad       2.0        5.000000    10.000000
# 4       TXN_3160411    Coffee       2.0        2.000000     4.000000
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0        2.000000     4.000000
# 9996    TXN_9659401     Juice       3.0        2.949984     3.000000
# 9997    TXN_5255387    Coffee       4.0        2.000000     8.000000
# 9998    TXN_7695629    Cookie       3.0        2.949984     3.000000
# 9999    TXN_6170729  Sandwich       3.0        4.000000    12.000000
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
cafe_sales.to_csv("clean_cafe_sales.csv")
